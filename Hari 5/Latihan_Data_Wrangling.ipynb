# %% [markdown]
# ## Latihan

# %% [markdown]
# 1. Gunakan dataset 'sales_data_latihan.csv'
# https://raw.githubusercontent.com/audit-ti/pjj-pengolahan-data-python/main/04.%20Data%20Preparation/dataset/sales_data_latihan.csv
# 2. Perbaiki format data:
# - Kolom sales seharusnya numerik (hapus Rp)
# - Kolom "Percent Growth" seharusnya numerik (tanpa tanda %)
# - Hilangkan spasi berlebih pada kolom Type
# 3. Buat laporan:
# - Jumlah Sales Berdasarkan Tipe
# - Ambil 3 customer dengan kenaikan tertinggi

# %% [markdown]
# #1. Impor library dan dataset

# %%
#import pandas library
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

#read data
df = pd.read_csv('https://raw.githubusercontent.com/audit-ti/pjj-pengolahan-data-python/main/04.%20Data%20Preparation/dataset/sales_data_latihan.csv')
df
# Out:
#    Customer Number     Customer Name                  Address         Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta      Company
# 1           552278    Smith Plumbing         Pasteur, Bandung      Company
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta   Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung      Company
# 4           651029         Harbor Co       Cilincing, Jakarta      Company
# 5           565600       Berkah Jaya        Antapani, Bandung   Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok     Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta     Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta     Individu
#
#              Sales Percent Growth
# 0      Rp162500000         30.00%
# 1      Rp101200000         10.00%
# 2         62500000            NaN
# ...

# %% [markdown]
# #2. Perbaikan format data

# %% [markdown]
# ##2.1 Kolom sales seharusnya numerik (hapus Rp)

# %%
df['Sales'] = df.Sales.str.replace('Rp','')
df['Sales'] = df.Sales.str.replace(',','')
df['Sales'] = df.Sales.astype('float')
df
# Out:
#    Customer Number     Customer Name                  Address         Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta      Company
# 1           552278    Smith Plumbing         Pasteur, Bandung      Company
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta   Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung      Company
# 4           651029         Harbor Co       Cilincing, Jakarta      Company
# 5           565600       Berkah Jaya        Antapani, Bandung   Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok     Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta     Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta     Individu
#
#            Sales Percent Growth
# 0 162,500,000.00         30.00%
# 1 101,200,000.00         10.00%
# 2  62,500,000.00            NaN
# ...

# %% [markdown]
# ##2.2 Kolom "Percent Growth" seharusnya numerik (tanpa tanda %)

# %%
df['Percent Growth'] = df['Percent Growth'].str.replace('%','')
df['Percent Growth'] = df['Percent Growth'].astype('float')
df
# Out:
#    Customer Number     Customer Name                  Address         Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta      Company
# 1           552278    Smith Plumbing         Pasteur, Bandung      Company
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta   Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung      Company
# 4           651029         Harbor Co       Cilincing, Jakarta      Company
# 5           565600       Berkah Jaya        Antapani, Bandung   Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok     Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta     Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta     Individu
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 1 101,200,000.00           10.00
# 2  62,500,000.00             NaN
# ...

# %% [markdown]
# ##2.3 Hilangkan spasi berlebih pada kolom Type

# %%
df['Type'] = df['Type'].str.strip()
df
# Out:
#    Customer Number     Customer Name                  Address        Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta     Company
# 1           552278    Smith Plumbing         Pasteur, Bandung     Company
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta  Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung     Company
# 4           651029         Harbor Co       Cilincing, Jakarta     Company
# 5           565600       Berkah Jaya        Antapani, Bandung  Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok    Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta    Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta    Individu
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 1 101,200,000.00           10.00
# 2  62,500,000.00             NaN
# ...

# %% [markdown]
# #3. Buat Laporan

# %% [markdown]
# ##3.1 Jumlah Sales Berdasarkan Tipe

# %%
#mengganti kolom yang isinya individu
df['Type'] = df['Type'].str.replace('Individu','Personal')
df
# Out:
#    Customer Number     Customer Name                  Address        Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta     Company
# 1           552278    Smith Plumbing         Pasteur, Bandung     Company
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta  Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung     Company
# 4           651029         Harbor Co       Cilincing, Jakarta     Company
# 5           565600       Berkah Jaya        Antapani, Bandung  Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok    Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta    Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta    Personal
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 1 101,200,000.00           10.00
# 2  62,500,000.00             NaN
# ...

# %%
#mengganti kolom yang isinya company
df['Type'] = df['Type'].str.replace('Company','Perusahaan')
df
# Out:
#    Customer Number     Customer Name                  Address        Type  \
# 0           100025    Quest Industry  Kebayoran Lama, Jakarta  Perusahaan
# 1           552278    Smith Plumbing         Pasteur, Bandung  Perusahaan
# 2           234775   ACME Industrial  Kebayoran Lama, Jakarta  Perusahaan
# 3           249000        Brekke LTD         Pasteur, Bandung  Perusahaan
# 4           651029         Harbor Co       Cilincing, Jakarta  Perusahaan
# 5           565600       Berkah Jaya        Antapani, Bandung  Perusahaan
# 6           897440       Rafee Ahmad          Sawangan, Depok    Personal
# 7           123156      Reza Pratama  Kebayoran Baru, Jakarta    Personal
# 8           138135      PT Berdikari  Kebayoran Lama, Jakarta  Perusahaan
# 9           748952  Alexander Samiun       Sleman, Jogjakarta    Personal
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 1 101,200,000.00           10.00
# 2  62,500,000.00             NaN
# ...

# %%
df[['Type','Sales']].groupby('Type').sum('Sales')
# Out:
#                       Sales
# Type
# Personal     189,650,000.00
# Perusahaan 1,115,350,000.00

# %% [markdown]
# ##3.2 Ambil 3 customer dengan kenaikan tertinggi

# %%
df.sort_values('Percent Growth', ascending=False).head(3)
# Out:
#    Customer Number   Customer Name                  Address        Type  \
# 0           100025  Quest Industry  Kebayoran Lama, Jakarta  Perusahaan
# 5           565600     Berkah Jaya        Antapani, Bandung  Perusahaan
# 7           123156    Reza Pratama  Kebayoran Baru, Jakarta    Personal
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 5 762,500,000.00           30.00
# 7  50,000,000.00           25.00

# %%
df.nlargest(3,'Percent Growth')
# Out:
#    Customer Number   Customer Name                  Address        Type  \
# 0           100025  Quest Industry  Kebayoran Lama, Jakarta  Perusahaan
# 5           565600     Berkah Jaya        Antapani, Bandung  Perusahaan
# 7           123156    Reza Pratama  Kebayoran Baru, Jakarta    Personal
#
#            Sales  Percent Growth
# 0 162,500,000.00           30.00
# 5 762,500,000.00           30.00
# 7  50,000,000.00           25.00
